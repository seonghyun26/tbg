# %%
import numpy as np

# %%
train = np.load("./2AA-1-large/all_train.npy", allow_pickle=True)
print(train)
# Out:
# {'VE': array([[ -5.3385463 ,   4.094408  ,  -7.8852215 , ...,  10.511713  ,
#          -3.1419315 ,  -0.97603595],
#        [ -8.058314  ,   3.8703113 ,  -4.7892895 , ...,  10.777511  ,
#          -2.1162674 ,  -2.989817  ],
#        [ -7.7938004 ,   4.308959  ,  -4.691519  , ...,   9.02072   ,
#          -3.3161674 ,  -4.8675137 ],
#        ...,
#        [ -5.155213  ,   4.2387824 ,   4.45607   , ...,   7.3419714 ,
#          -4.8614483 ,  -7.50547   ],
#        [ -4.969227  ,   5.512296  ,   5.438989  , ...,   0.66277385,
#           1.505236  , -11.370625  ],
#        [ -2.6713462 ,   3.0254183 ,   9.378633  , ...,  -2.68004   ,
#           0.43751568, -10.029399  ]], dtype=float32), 'LI': array([[  0.44425786,  -0.6890425 , -11.20594   , ...,  -2.6706147 ,
#          -5.162766  ,   5.1651506 ],
#        [ -1.3252366 ,  -7.1598635 ,  -8.769019  , ...,  -4.2058253 ,
#           0.37890762,   8.050672  ],
#        [  2.822258  ,  -6.1238937 ,  -8.039829  , ...,  -5.190593  ,
# ...

# %%
data = train[np.newaxis]
data[0]['VE'].shape
# Out:
# (49000, 102)
